# %% [markdown]
# ## D Tale

# %%
# !pip install DTale

# %%
import seaborn as sns
df = sns.load_dataset('titanic')

# %%
import dtale
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://AviTech:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# !pip install sweetviz

# %%
import sweetviz as sv
report = sv.analyze(df)
report.show_html('sweet.report.html')
# Out:
#                                              |     | [  0%]   00:00 -> (? left)
# Report sweet.report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
import matplotlib.pyplot as plt
